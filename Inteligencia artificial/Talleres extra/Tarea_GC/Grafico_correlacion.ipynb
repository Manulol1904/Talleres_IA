# %% [markdown]
# ## Grafico de correlación

# %% [markdown]
# ### Creado a partir de un Dataframe creado por codigo

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Creamos un conjunto de datos de ejemplo
df = pd.DataFrame({
    "edad": [18, 22, 25, 30, 35, 40, 50],
    "ingresos": [800, 1200, 2000, 3000, 4000, 5000, 7000],
    "gastos": [500, 700, 1200, 1800, 2500, 3200, 4000]
})

# ===== MATRIZ DE CORRELACIÓN =====
correlacion = df.corr()
print(correlacion)  # calcula la correlación entre todas las columnas
sns.heatmap(correlacion, annot=True, cmap="coolwarm", center=0)
plt.title("Matriz de correlación")
plt.show()

# ===== DIAGRAMA DE DISPERSIÓN =====
sns.scatterplot(data=df, x="edad", y="ingresos")
plt.title("Relación entre Edad e Ingresos")
plt.show()
# Out:
#               edad  ingresos    gastos
# edad      1.000000  0.998658  0.994102
# ingresos  0.998658  1.000000  0.995843
# gastos    0.994102  0.995843  1.000000
